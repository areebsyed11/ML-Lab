# %% [markdown]
# ML LAB 01
# 22k-4042

# %% [markdown]
# QUESTION #1

# %%
import numpy as np
import pandas as pd

data=np.array([
    ['Muneeb Ur Rehman',45,'Poor','Average','Partial','Low'],
    ['Jameel Khan',35,'Average','Good','Partial','Low'],
    ['Ahad Raza',30,'Poor', 'Poor','Partial','Low'],
    ['Babar Azam',40,'Good','Good','Full','High'],
    ['Fakhar Zaman',38,'Average','Average','Partial','Medium'],
    ['Alex Hales',42,'Poor','Average','Partial','Low'],
    ['Virat kholi',28,'Poor','Poor','None','Low'],
    ['Joe Root',46,'Good','Good','Full','High'],
    ['Ab devellier',48,'Average','Good','Partial','Medium'],
    ['Brendon Mcullum',49,'Good','Good','Full','Medium']])

df=pd.DataFrame(data, columns=['name','test_score', 'writing_skills', 'reading_skill', 'cover_syllabus', 'attendance'])
df
# Out:
#                name test_score writing_skills reading_skill cover_syllabus  \
# 0  Muneeb Ur Rehman         45           Poor       Average        Partial
# 1       Jameel Khan         35        Average          Good        Partial
# 2         Ahad Raza         30           Poor          Poor        Partial
# 3        Babar Azam         40           Good          Good           Full
# 4      Fakhar Zaman         38        Average       Average        Partial
# 5        Alex Hales         42           Poor       Average        Partial
# 6       Virat kholi         28           Poor          Poor           None
# 7          Joe Root         46           Good          Good           Full
# 8      Ab devellier         48        Average          Good        Partial
# 9   Brendon Mcullum         49           Good          Good           Full
#
#   attendance
# 0        Low
# 1        Low
# 2        Low
# 3       High
# 4     Medium
# 5        Low
# 6        Low
# 7       High
# ...

# %% [markdown]
# QUESTION#2

# %%
#B
import pandas as pd
df= pd.read_csv('cancer patient data sets.csv')
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
#C
unique=df['Level'].unique()
unique
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
#D
#total number of columns
print("Total Rows and Columns ",df.shape)
print("Columns ",df.shape[1])
# Out:
# Total Rows and Columns  (1000, 26)
# Columns  26

# %%
df.head(50)
# Out:
#     index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0       0         P1   33       1              2            4             5
# 1       1        P10   17       1              3            1             5
# 2       2       P100   35       1              4            5             6
# 3       3      P1000   37       1              7            7             7
# 4       4       P101   46       1              6            8             7
# 5       5       P102   35       1              4            5             6
# 6       6       P103   52       2              2            4             5
# 7       7       P104   28       2              3            1             4
# 8       8       P105   35       2              4            5             6
# 9       9       P106   46       1              2            3             4
# 10     10       P107   44       1              6            7             7
# ...

# %%
df.tail(30)
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 970    970       P972   48       2              6            8             7
# 971    971       P973   36       2              2            1             5
# 972    972       P974   31       2              3            2             4
# 973    973       P975   38       2              1            2             3
# 974    974       P976   35       1              6            8             7
# 975    975       P977   44       1              6            7             7
# 976    976       P978   33       1              2            4             5
# 977    977       P979   45       1              3            1             4
# 978    978        P98   26       2              8            8             7
# 979    979       P980   53       1              3            1             4
# 980    980       P981   35       2              4            5             6
# ...

# %%
print("Memory Size ",df.memory_usage(deep=True).sum())
print("Dimensions ",df.ndim)
print("Size of dataset ",df.size)
# Out:
# Memory Size  298386
# Dimensions  2
# Size of dataset  26000

# %%
#E
print("Columns ",df.shape[1])
print("Samples ",df.shape[0])
# Out:
# Columns  26
# Samples  1000

# %%
#F
import matplotlib.pyplot as plt

values = df['Level'].value_counts()
unique = values.index 
plt.bar(unique,values)
plt.title('Count of Records per Level')
plt.xlabel('Level')
plt.ylabel('Count')
plt.show()
print(values)
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
#G
new_df = df.loc[550:900, ['Gender', 'Air Pollution', 'Alcohol use', 'Dust Allergy', 
                                'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease', 
                                'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 
                                'Chest Pain', 'Coughing of Blood']]


new_df.to_csv('new_data.csv', index=False)
dff = pd.read_csv('new_data.csv')
dff.describe()
# Out:
#            Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  351.000000     351.000000   351.000000    351.000000
# mean     1.396011       3.988604     4.749288      5.319088
# std      0.489765       2.042376     2.622941      1.921504
# min      1.000000       1.000000     1.000000      1.000000
# 25%      1.000000       2.000000     2.000000      4.000000
# 50%      1.000000       4.000000     5.000000      6.000000
# 75%      2.000000       6.000000     7.000000      7.000000
# max      2.000000       8.000000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count            351.000000    351.000000            351.000000
# mean               4.974359      4.726496              4.472934
# std                2.084480      2.112374              1.823257
# min                1.000000      1.000000              1.000000
# 25%                3.000000      3.000000              3.000000
# ...

# %%
#H
new_dff = df.iloc[-20:, df.columns.get_indexer(['Shortness of Breath', 'Wheezing', 
                                                'Swallowing Difficulty', 'Clubbing of Finger Nails', 
                                                'Frequent Cold'])]

new_dff.to_csv('new_data2.csv', index=False)
dff2 = pd.read_csv('new_data2.csv')
dff2.describe()
# Out:
#        Shortness of Breath   Wheezing  Swallowing Difficulty  \
# count            20.000000  20.000000               20.00000
# mean              5.400000   3.650000                3.95000
# std               2.542274   2.621269                2.37254
# min               2.000000   1.000000                1.00000
# 25%               3.750000   1.000000                1.75000
# 50%               5.000000   2.000000                4.00000
# 75%               7.500000   7.000000                6.00000
# max               9.000000   7.000000                8.00000
#
#        Clubbing of Finger Nails  Frequent Cold
# count                  20.00000      20.000000
# mean                    4.05000       4.650000
# std                     1.79106       1.496487
# min                     2.00000       2.000000
# 25%                     2.00000       4.000000
# 50%                     4.00000       4.000000
# 75%                     5.00000       6.000000
# ...

# %%
#I
records = [110, 220, 360, 440, 656, 778, 202, 889]
data = df.loc[records]
print('Average of alcohol use in these records ',data['Alcohol use'].mean())
data
# Out:
# Average of alcohol use in these records  5.625
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 110    110       P198   18       2              6            8             7
# 220    220       P297   25       2              4            5             6
# 360    360       P422   19       1              3            2             4
# 440    440       P495   44       1              6            7             7
# 656    656        P69   52       1              6            8             7
# 778    778         P8   27       2              3            1             4
# 202    202       P280   53       1              6            8             7
# 889    889         P9   73       1              5            6             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 110                     7             7                     6  ...        3
# ...

# %% [markdown]
# QUESTION#3

# %%
#A
#Scatterplot
import seaborn as sns
x1=df['Genetic Risk']
x2=df['Age']
sns.scatterplot(x=x1,y=x2, hue=df['Level'])
# Out:
# <Axes: xlabel='Genetic Risk', ylabel='Age'>

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Muneeb\AppData\Local\Temp\ipykernel_14248\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Alcohol use'])
# Out:
# <Axes: ylabel='Alcohol use'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 67.,  98., 145., 259., 111., 186.,  63.,  10.,  51.,  10.]),
#  array([14. , 19.9, 25.8, 31.7, 37.6, 43.5, 49.4, 55.3, 61.2, 67.1, 73. ]),
#  <BarContainer object of 10 artists>)

# %%
#B

numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(data=numeric_df.corr(), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
#C
plt.subplot(1, 2, 1)
sns.histplot(df['Age'], kde=True, bins=20)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df['Frequent Cold'], kde=True, bins=20)
plt.title('Distribution of Frequent Cold')
plt.xlabel('Frequent Cold')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
sns.boxplot(df['Obesity'])
plt.title('Boxplot of Obesity Feature')
# Out:
# Text(0.5, 1.0, 'Boxplot of Obesity Feature')
